# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib

# %%
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)
pd.set_option('display.notebook_repr_html', True)
matplotlib.rcParams['figure.figsize'] = (10.0, 10.0)

# %%
dfcars = pd.read_csv("data/mtcars.csv")

# %%
dfcars.head()
# Out:
#           Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2

# %%
dfcars = dfcars.rename(columns={"Unnamed: 0" : "name"})

# %%
dfcars.head()
# Out:
#                 name   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2

# %%
dfcars.shape
# Out:
# (32, 12)

# %%
dfcars['maker'] = dfcars['name'].apply(lambda x:x.split(' ')[0])
dfcars.head()
# Out:
#                 name   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb   maker
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4   Mazda
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4   Mazda
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1  Datsun
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1  Hornet
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2  Hornet

# %%
dfcars.maker.unique()
# Out:
# array(['Mazda', 'Datsun', 'Hornet', 'Valiant', 'Duster', 'Merc',
#        'Cadillac', 'Lincoln', 'Chrysler', 'Fiat', 'Honda', 'Toyota',
#        'Dodge', 'AMC', 'Camaro', 'Pontiac', 'Porsche', 'Lotus', 'Ford',
#        'Ferrari', 'Maserati', 'Volvo'], dtype=object)

# %%
av_mpg = dfcars.groupby('maker').mpg.mean()
av_mpg
# Out:
# maker
# AMC         15.200000
# Cadillac    10.400000
# Camaro      13.300000
# Chrysler    14.700000
# Datsun      22.800000
# Dodge       15.500000
# Duster      14.300000
# Ferrari     19.700000
# Fiat        29.850000
# Ford        15.800000
# Honda       30.400000
# Hornet      20.050000
# Lincoln     10.400000
# Lotus       30.400000
# Maserati    15.000000
# Mazda       21.000000
# Merc        19.014286
# Pontiac     19.200000
# Porsche     26.000000
# Toyota      27.700000
# Valiant     18.100000
# Volvo       21.400000
# Name: mpg, dtype: float64

# %%
sns.color_palette()
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
sns.palplot(sns.color_palette())

# %%
output = sns.choose_colorbrewer_palette('qualitative')
# Out:
# interactive(children=(Dropdown(description='name', options=('Set1', 'Set2', 'Set3', 'Paired', 'Accent', 'Paste…

# %%
sns.palplot(output)

# %%
plt.figure(figsize=(10,10))
av_mpg.plot(kind= 'barh',color = output[1])

# %%
sns.set_context("notebook")
plt.figure(figsize=(10,10))
ax = plt.gca()
av_mpg2 = av_mpg.sort_values()
av_mpg2.plot(kind= 'barh',color = output[1])
plt.grid(axis='x',color = 'white',linestyle = "-")
sns.despine(left=True , bottom=True)
plt.tick_params(axis = 'both' ,which = 'both' , length = 0)
plt.xlabel("Average MPG")
# Out:
# Text(0.5,0,'Average MPG')

# %%
plt.figure(figsize=(8, 8))
av_mpg2 = av_mpg.sort_values()
makes = av_mpg2.index
speed = av_mpg2.values
nums = np.arange(len(av_mpg2))
plt.barh(nums,speed)
yticks = plt.yticks(nums,makes)
xticks = plt.xticks(plt.xticks()[0],['']*len(plt.xticks()[0]))
sns.despine(left=True,bottom=True)
plt.tick_params(axis='both',which = 'both' , length = 0)
plt.grid(axis='x',color = 'white' , linestyle = '-')
for p,c,ch in zip(nums,makes,speed):
    plt.annotate(str(round(ch,2)),xy = (ch+0.1,p),va = 'center')

# %%
av_mpg.plot(kind= 'barh',color = output[1])

# %%
dfcars.mpg.hist()

# %%
plt.hist(dfcars.mpg.values,alpha = 0.4)
sns.despine()
plt.xlabel("MPG")
# Out:
# Text(0.5,0,'MPG')

# %%
sns.set()

# %%
dfcars.mpg.hist()

# %%
sns.reset_defaults()

# %%
dfcars.mpg.hist()

# %%
with sns.axes_style("whitegrid"):
    plt.hist(dfcars.mpg.values, bins=20)
    plt.xlim([5,40])
    plt.ylim([0,8])
    plt.axvline(dfcars.mpg.mean(),0,0.75,color = 'r',label = 'mean')
    plt.legend()
    plt.xlabel("MPG")
    plt.ylabel("Counts")
    plt.title("Cars Miles Per Gallon Histogram")

# %%
sns.kdeplot(dfcars.mpg)
plt.axvline(dfcars.mpg.mean(),0,0.95,color = 'r',label = "mean")
plt.legend()
# Out:
# C:\Users\ashwi\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(dfcars.mpg,label="MPG")
plt.legend()
# Out:
# C:\Users\ashwi\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plt.scatter(dfcars.wt,dfcars.mpg,marker="+")

# %%
plt.plot(dfcars.mpg , dfcars.wt , marker = 'o',linestyle = 'none')

# %%
sns.regplot(x='mpg',y='wt',data=dfcars)
# Out:
# C:\Users\ashwi\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.boxplot(x='am',y='mpg',data=dfcars)

# %%
sns.violinplot(x='am',y='mpg',data=dfcars)
# Out:
# C:\Users\ashwi\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.violinplot(x='cyl',y='mpg',hue = 'am',data=dfcars,split=True)
# Out:
# C:\Users\ashwi\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
g = sns.FacetGrid(dfcars,col='cyl',hue = 'am')
g.map(plt.scatter,'mpg','wt')

# %%
g = sns.PairGrid(dfcars, vars=['mpg', 'hp', 'wt', 'qsec', 'disp'], hue="am")
g.map_diag(sns.kdeplot)
g.map_offdiag(plt.scatter, s=15)
# Out:
# C:\Users\ashwi\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
g = sns.PairGrid(dfcars,hue='am')
g.map_diag(sns.kdeplot)
g.map_offdiag(plt.scatter, s=15)
# Out:
# C:\Users\ashwi\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\ashwi\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\ashwi\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# C:\Users\ashwi\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
